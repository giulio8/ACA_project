# %% [markdown]
# ## Import libraries

# %%
try:
  import google.colab
  IN_COLAB = True
except:
  IN_COLAB = False

if IN_COLAB:
    from google.colab import drive

    drive.mount('/gdrive')
    # %cd /gdrive/My Drive/[2024-2025] AN2DL/Homework 1
    # !pip install keras_cv
# Out:
# Drive already mounted at /gdrive; to attempt to forcibly remount, call drive.mount("/gdrive", force_remount=True).
# /gdrive/.shortcut-targets-by-id/1M1TW6PTeAUJgqEz6TK_sPPBirCoPACP_/Homework 1
# Requirement already satisfied: keras_cv in /usr/local/lib/python3.10/dist-packages (0.9.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras_cv) (24.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.10/dist-packages (from keras_cv) (1.4.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.10/dist-packages (from keras_cv) (2024.9.11)
# Requirement already satisfied: tensorflow-datasets in /usr/local/lib/python3.10/dist-packages (from keras_cv) (4.9.7)
# Requirement already satisfied: keras-core in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.1.7)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.10/dist-packages (from keras_cv) (0.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (2.32.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kagglehub->keras_cv) (4.66.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (1.26.4)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.0.8)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (3.12.1)
# Requirement already satisfied: dm-tree in /usr/local/lib/python3.10/dist-packages (from keras-core->keras_cv) (0.1.8)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (8.1.7)
# Requirement already satisfied: immutabledict in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.2.0)
# Requirement already satisfied: promise in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: protobuf>=3.20 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (4.25.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (5.9.5)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (17.0.0)
# Requirement already satisfied: simple-parsing in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.1.6)
# Requirement already satisfied: tensorflow-metadata in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.13.1)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (2.5.0)
# Requirement already satisfied: toml in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: array-record>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-datasets->keras_cv) (0.5.1)
# Requirement already satisfied: etils>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (1.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (4.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (2024.10.0)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (6.4.5)
# Requirement already satisfied: zipp in /usr/local/lib/python3.10/dist-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0; python_version < "3.11"->tensorflow-datasets->keras_cv) (3.20.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->kagglehub->keras_cv) (2024.8.30)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from promise->tensorflow-datasets->keras_cv) (1.16.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->keras-core->keras_cv) (2.18.0)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /usr/local/lib/python3.10/dist-packages (from simple-parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: googleapis-common-protos<2,>=1.52.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow-metadata->tensorflow-datasets->keras_cv) (1.65.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)

# %% [markdown]
# ## Import preprocessed data

# %%
# Set seed for reproducibility
seed = 42

# Import necessary libraries
import os

# Set environment variables before importing modules
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
os.environ['PYTHONHASHSEED'] = str(seed)
os.environ['MPLCONFIGDIR'] = os.getcwd() + '/configs/'

# Suppress warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=Warning)

# Import necessary modules
import logging
import random
import numpy as np

# Set seeds for random number generators in NumPy and Python
np.random.seed(seed)
random.seed(seed)

# Import TensorFlow and Keras
import tensorflow as tf
from tensorflow import keras as tfk
from tensorflow.keras import layers as tfkl

# Set seed for TensorFlow
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# Reduce TensorFlow verbosity
tf.autograph.set_verbosity(0)
tf.get_logger().setLevel(logging.ERROR)
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Print TensorFlow version
print(tf.__version__)

# Import other libraries
import requests
from io import BytesIO
from PIL import Image
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import seaborn as sns
import keras_cv

# Configure plot display settings
sns.set(font_scale=1.4)
sns.set_style('white')
plt.rc('font', size=14)
# %matplotlib inline
# Out:
# 2.17.0

# %% [markdown]
# ### Utils functions

# %%
from datetime import datetime, timedelta
def time():
    if IN_COLAB:
        return datetime.now() + timedelta(hours=1)
    else:
        return datetime.now()

# Function to stringify the layer configurations
def stringify_augmentation(augmentation_pipeline):
    layer_descriptions = []
    for layer in augmentation_pipeline.layers:
        layer_name = layer.__class__.__name__
        # Filter out only essential parameters
        essential_params = {k: v for k, v in layer.get_config().items() if k in ["mode", "height_factor", "width_factor", "factor", "fill_mode", "interpolation"]}
        layer_desc = f"{layer_name}(" + ", ".join(f"{k}={v}" for k, v in essential_params.items()) + ")"
        layer_descriptions.append(layer_desc)
    return "[" + ", ".join(layer_descriptions) + "]"

# %%
X, y = np.load('Preprocessed_data/X.npy'), np.load('Preprocessed_data/y.npy')
# convert y to 1D array
y = y.squeeze()

class_names = np.load('Preprocessed_data/class_names.npy')
print(X.shape, y.shape)
print(class_names)
# Out:
# (11959, 96, 96, 3) (11959,)
# ['class_0' 'class_1' 'class_2' 'class_3' 'class_4' 'class_5' 'class_6'
#  'class_7']

# %% [markdown]
# ### Plot distribution of classes

# %%
def plot_class_distribution(y_train, class_names):
    # Set seaborn style for the plot
    sns.set_style("whitegrid")
    plt.figure(figsize=(18, 6))

    # Calculate class distributions for training and test sets
    train_dist = np.bincount(y_train)


    # Create x positions and set bar width
    x = np.arange(len(class_names))
    width = 0.35

    # Plot bars for training and test distributions
    plt.bar(x - width / 2, train_dist, width, label='Training', color='#2ecc71', alpha=0.7)

    # Customise plot title and labels
    plt.title('Class Distribution', pad=20, fontsize=14)
    plt.xlabel('Classes')
    plt.ylabel('Number of Images')

    # Set class names as x-axis labels with rotation
    plt.xticks(x, class_names, rotation=45, ha='right')

    # Add legend for training and test distributions
    plt.legend(loc='lower right')

    # Adjust layout for optimal spacing
    plt.tight_layout()
    plt.show()

# Execute function to plot class distribution
plot_class_distribution(y, class_names)

# %% [markdown]
# ## Generate validation split(s)

# %%
# Split validation set into validation and test sets with stratification
X_train, X_val, y_train, y_val = train_test_split(X, y, random_state=seed, test_size=0.2, stratify=y)

# Convert class labels to categorical format for training, validation, and test sets
y_train = tfk.utils.to_categorical(y_train, num_classes=len(class_names))
y_val = tfk.utils.to_categorical(y_val, num_classes=len(class_names))

# Print shapes of the datasets
print(f"X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"X_val shape: {X_val.shape}, y_val shape: {y_val.shape}")
# Out:
# X_train shape: (9567, 96, 96, 3), y_train shape: (9567, 8)
# X_val shape: (2392, 96, 96, 3), y_val shape: (2392, 8)

# %% [markdown]
# ## Optionally use Weighted loss
# we can avoid setting this parameter in the training function if we don't want to weight the loss

# %%
class_counts = np.bincount(np.argmax(y_train, axis=1))  # Conta le occorrenze per ogni classe
total_samples = len(y_train)

# Calcola i pesi delle classi come frequenza inversa
class_weights = {i: total_samples / (len(class_counts) * count) for i, count in enumerate(class_counts)}
print("Class weights:", class_weights)
# Out:
# Class weights: {0: 1.753482404692082, 1: 0.6853151862464183, 2: 1.3777361751152073, 3: 0.7377390499691548, 4: 1.7612297496318114, 5: 1.506139798488665, 6: 0.6415638412017167, 7: 0.9101027397260274}

# %% [markdown]
# ## Define a Model

# %%
# Set some variables for convenience to refer to the chosen architecture

NET_NAME = 'EfficientNetB4'
# (OPTIONAL) this will be added to the model name to identify the run in the folder, logs...
IDENTIFIER = ""
MODEL_NAME = NET_NAME + ("_" + IDENTIFIER if IDENTIFIER else "")

# this will be added as a file in the model folder to describe the run
RUN_DESCRIPTION = "abbiamo scelto efficientnetb4 come modello, abbiamo fatto questa scelta per questo motivo ecc ecc"

# Set the hyperparameters (this metrics will be saved with the weights)
# These refers specifically to the first run (transfer learning)
hyperparameters = {
    'batch_size': 256,
    'epochs': 200,
    'lr': 0.001,
    'weight_decay': 0.001,#0.001,
    'patience': 10,
    'optimizer': 'adam', # to change manually from here if needed
    'weighted_loss': True,
    'label_smoothing': 0.1, # set None to deactivate
    'mixup': False,
    'mixup_alpha': 0.2,
    'mixup_prob': 0.5,
    'transfer_learning': 'full'
}

# %% [markdown]
# ### Select a pretrained network from keras.application and optionally display it (showing number of layers, parameters etc)

# %%
# Initialise chosen model with pretrained weights, for transfer learning
net = tfk.applications.EfficientNetB4(
    input_shape=(96, 96, 3),
    include_top=False,
    weights='imagenet',#mettere image net, prima era none
    pooling='avg'
)

# Display a summary of the model architecture
#net.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
#tfk.utils.plot_model(net, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ### Choose augmentation layer

# %%
import keras_cv
# Apply data augmentation for training robustness
"""
augmentation = tf.keras.Sequential([
    tfkl.RandomFlip("horizontal"),
    tfkl.RandomTranslation(0.3, 0.3),
    tfkl.RandomRotation(0.5),
    tfkl.RandomZoom(0.4),
    tfkl.RandomContrast(0.7),
    tfkl.RandomBrightness(0.4),
    keras_cv.layers.RandomSharpness(factor=(0.3, 0.8), value_range=(0, 255)),
    tfkl.GaussianNoise(stddev=0.1),
    #keras_cv.layers.RandomChannelShift(value_range=(0, 255), factor=0.05, channels=3),
    #keras_cv.layers.RandomColorDegeneration(factor=0.1),
    keras_cv.layers.RandomSaturation(factor=0.05),
    #keras_cv.layers.RandomHue(factor=0.05, value_range=(0, 255)),
    keras_cv.layers.RandomContrast(factor=0.05, value_range=(0, 255)),
    #keras_cv.layers.Solarization(value_range=(0, 255), addition_factor=0.0, threshold_factor=0.2)

], name='preprocessing')
"""

AUTO = tf.data.AUTOTUNE
BATCH_SIZE = 128

IMAGE_SIZE = 96
"""
layers = keras_cv.layers.RandAugment(
    value_range=(0, 255), augmentations_per_image=3, magnitude=0.5
)
"""
def to_dict(image, label):
    image = tf.cast(image, tf.float32)
    label = tf.cast(label, tf.float32)
    return {"images": image, "labels": label}

layers = keras_cv.layers.RandAugment.get_standard_policy(
    value_range=(0, 255), magnitude=0.3, magnitude_stddev=0.3
)

layers = layers + [keras_cv.layers.GridMask()]

random_pipeline = keras_cv.layers.RandomAugmentationPipeline(
    layers=layers, augmentations_per_image=3
)
cut_mix = keras_cv.layers.CutMix()
mix_up = keras_cv.layers.MixUp(alpha=0.2)

def cutmix_and_mixup(X, y):
  # we must convert to a dictionary to apply these transfromations
  X = to_dict(X, y)
  #X = cut_mix(X)
  X = mix_up(X)
  return X['images'], X['labels']

train_ds_rand = (
    tf.data.Dataset.from_tensor_slices((X_train, y_train))
    .shuffle(BATCH_SIZE * 100)
    .batch(BATCH_SIZE)
    .map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    )
    .map(
        lambda x, y: (random_pipeline(tf.cast(x, tf.uint8)), y),
        num_parallel_calls=AUTO,
    )
    .map(
        lambda x, y: (cutmix_and_mixup(x, y)),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset.from_tensor_slices((X_val, y_val))
    .batch(BATCH_SIZE)
    .map(
        lambda x, y: (tf.image.resize(x, (IMAGE_SIZE, IMAGE_SIZE)), y),
        num_parallel_calls=AUTO,
    )
    .prefetch(AUTO)
)




# Visualize examples of augmented images
def visualize_augmented_images(image, augmentation):
    # plot original image together with other 8 versions of the same image, in the same plot
    fig, ax = plt.subplots(3, 3, figsize=(20, 20))
    ax = ax.ravel()
    ax[0].imshow(np.array(image, dtype='uint8'))
    ax[0].set_title('Original image')
    ax[0].axis('off')
    for i in range(1, 9):
        augmented_image = augmentation(tf.expand_dims(image, 0))

        ax[i].imshow(np.array(augmented_image[0], dtype='uint8'))
        ax[i].set_title(f'Augmented image {i}')
        ax[i].axis('off')



"""# Load some example image stratified by class
indexes = [np.where(np.argmax(y_train, axis=1) == i)[0][0] for i in range(len(class_names))]
indexes = np.random.choice(indexes, 3)
example_images = X_train[indexes]
# Visualize augmented images
for i in range(len(indexes)):
    visualize_augmented_images(example_images[i], augmentation)"""
# Out:
# '# Load some example image stratified by class\nindexes = [np.where(np.argmax(y_train, axis=1) == i)[0][0] for i in range(len(class_names))]\nindexes = np.random.choice(indexes, 3)\nexample_images = X_train[indexes]\n# Visualize augmented images\nfor i in range(len(indexes)):\n    visualize_augmented_images(example_images[i], augmentation)'

# %% [markdown]
# ### Add mixup images generator to include mixed up images (not a layer, but a preprocessing at batch generator level)

# %%
from tensorflow.keras.utils import Sequence

# Converti le etichette in float32 per essere compatibili con MixUp
y_train = tf.cast(y_train, dtype=tf.float32)
y_val = tf.cast(y_val, dtype=tf.float32)

# Generatore di dati personalizzato con MixUp applicato parzialmente
class PartialMixupDataGenerator(Sequence):
    def __init__(self, images, labels, batch_size=64, mixup_alpha=0.2, mixup_prob=0.5, shuffle=True):
        self.images = images
        self.labels = labels
        self.batch_size = batch_size
        self.mixup = keras_cv.layers.MixUp(alpha=mixup_alpha)
        self.mixup_prob = mixup_prob  # Probabilità di applicare MixUp
        self.shuffle = shuffle
        self.on_epoch_end()

    def __len__(self):
        return int(np.ceil(len(self.images) / self.batch_size))

    def __getitem__(self, index):
        # Estrai un batch di indici
        batch_indices = tf.constant(self.indices[index * self.batch_size:(index + 1) * self.batch_size])
        batch_images = tf.gather(self.images, batch_indices)
        batch_labels = tf.gather(self.labels, batch_indices)

        # Applica MixUp solo con una certa probabilità
        if np.random.rand() < self.mixup_prob:
            mixed_data = self.mixup({'images': batch_images, 'labels': batch_labels})
            batch_images, batch_labels = mixed_data['images'], mixed_data['labels']

        return batch_images, batch_labels  # Ritorna batch mixato/non-mixato

    def on_epoch_end(self):
        # Mescola i dati a fine epoca se shuffle è True
        self.indices = np.arange(len(self.images))
        if self.shuffle:
            np.random.shuffle(self.indices)

if hyperparameters['mixup']:
    # Crea un'istanza del generatore di dati
    train_generator = PartialMixupDataGenerator(
        images=X_train,
        labels=y_train,
        batch_size=hyperparameters['batch_size'],
        mixup_alpha=hyperparameters['mixup_alpha'],
        mixup_prob=hyperparameters['mixup_prob']
    )

# %% [markdown]
# ### Fully visualize the crap we are feeding into the network

# %%
# Visualize some example of a batch with MixUp applied, and also augmented
if hyperparameters['mixup']:
    # Estrai un batch di immagini e etichette
    batch_images, batch_labels = train_generator[8]
    # Visualizza le immagini del batch
    for i in range(len(batch_images[:3])):
        visualize_augmented_images(batch_images[i], augmentation)
else:
    sample_images, _ = next(iter(train_ds_rand))
    plt.figure(figsize=(10, 10))
    for i, image in enumerate(sample_images[:9]):
      ax = plt.subplot(3, 3, i + 1)
      plt.imshow(image.numpy().astype("int"))
      plt.axis("off")

# %% [markdown]
# OPTIMIZER

# %%
# Early stopping helps as it stops training if val_loss(validation score) does not decrease.
"""
# !pip install tensorflow_addons
import tensorflow_addons as tfa


lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=100, decay_rate=0.96,
    staircase=True)


def Ranger(sync_period=6,
           slow_step_size=0.5,
           learning_rate=0.001,
           beta_1=0.9,
           beta_2=0.999,
           epsilon=1e-7,
           weight_decay=0.,
           amsgrad=False,
           sma_threshold=5.0,
           total_steps=0,
           warmup_proportion=0.1,
           min_lr=0.,
           name="Ranger"):
    inner = tfa.optimizers.RectifiedAdam(learning_rate, beta_1, beta_2, epsilon, weight_decay, amsgrad, sma_threshold, total_steps, warmup_proportion, min_lr, name)
    optim = tfa.optimizers.Lookahead(inner, sync_period, slow_step_size, name)
    return optim
"""
# Out:
# '\n!pip install tensorflow_addons\nimport tensorflow_addons as tfa\n\n\nlr_schedule = ExponentialDecay(\n    initial_learning_rate=1e-3,\n    decay_steps=100, decay_rate=0.96,\n    staircase=True)\n\n\ndef Ranger(sync_period=6,\n           slow_step_size=0.5,\n           learning_rate=0.001,\n           beta_1=0.9,\n           beta_2=0.999,\n           epsilon=1e-7,\n           weight_decay=0.,\n           amsgrad=False,\n           sma_threshold=5.0,\n           total_steps=0,\n           warmup_proportion=0.1,\n           min_lr=0.,\n           name="Ranger"):\n    inner = tfa.optimizers.RectifiedAdam(learning_rate, beta_1, beta_2, epsilon, weight_decay, amsgrad, sma_threshold, total_steps, warmup_proportion, min_lr, name)\n    optim = tfa.optimizers.Lookahead(inner, sync_period, slow_step_size, name)\n    return optim\n'

# %%
from tensorflow.keras.optimizers import Lion
from tensorflow.keras.optimizers.schedules import ExponentialDecay

lr_schedule = ExponentialDecay(
    initial_learning_rate=1e-3,
    decay_steps=100, decay_rate=0.96,
    staircase=True)

optimizer = Lion(
    learning_rate=lr_schedule,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=1e-2,
    use_ema=False  # Setta True se vuoi usare EMA, ma normalmente è disattivato per Lion
)

# %% [markdown]
# ### Add preprocessing and augmentation layers to the initial stage of the model ("in front" of the selected network)

# %%
from tensorflow.keras.applications.efficientnet import preprocess_input



# Freeze all layers in net to use it solely as a feature extractor
net.trainable = False

# Define input layer with shape matching the input images
inputs = tfk.Input(shape=(96, 96, 3), name='input_layer')

#x = preprocess_input(inputs)
x = tfkl.GaussianNoise(stddev=0.1)(inputs)
#x = augmentation(x)
#x = augmentation(inputs)
x = net(x)
# Pass augmented inputs through the network feature extractor
#x = net(x)

#see if it's necessary to add a dense layer, in general is added in this part
#x = tfkl.Dense(256, activation='relu')(x)

# Add a dropout layer for regularisation
x = tfkl.Dropout(0.3, name='dropout')(x)


# Add final Dense layer for classification with softmax activation
outputs = tfkl.Dense(y_train.shape[-1], activation='softmax', dtype='float32', name='output')(x)

# Define the complete model linking input and output
tl_model = tfk.Model(inputs=inputs, outputs=outputs, name='model')

# Compile the model with categorical cross-entropy loss and Adam optimiser
tl_model.compile(loss=tfk.losses.CategoricalCrossentropy(label_smoothing=hyperparameters['label_smoothing']), optimizer=optimizer, metrics=['accuracy'])#optimizer=tfk.optimizers.Adam(hyperparameters["lr"], weight_decay=hyperparameters['weight_decay'])

# Display a summary of the model architecture
#tl_model.summary(expand_nested=True)

# Display model architecture with layer shapes and trainable parameters
#tfk.utils.plot_model(tl_model, expand_nested=True, show_trainable=True, show_shapes=True, dpi=70)

# %% [markdown]
# ## Train the model

# %% [markdown]
# ### First we use transfer learning

# %%
# Train the model
tl_history = tl_model.fit(
    train_ds_rand,
    batch_size=(hyperparameters['batch_size'] if not hyperparameters['mixup'] else None),
    epochs=hyperparameters['epochs'],
    validation_data=val_ds,
    class_weight=(class_weights if hyperparameters['weighted_loss'] else None),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=hyperparameters['patience'], restore_best_weights=True)]
).history

# Calculate and print the best validation accuracy achieved
final_val_accuracy = round(max(tl_history['val_accuracy']) * 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
run_dir_name = MODEL_NAME + "_" + str(final_val_accuracy) + "__" + time().strftime("_%Y-%m-%d_%H.%M")
model_filename = 'weights.keras'
os.makedirs("weights/transfer_learning/"+ run_dir_name, exist_ok=True)
model_filepath = "weights/transfer_learning/"+ run_dir_name + "/" + model_filename
tl_model.save(model_filepath)

# Free memory by deleting the model instance
del tl_model
# Out:
# Epoch 1/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 85s 619ms/step - accuracy: 0.2897 - loss: 1.9447 - val_accuracy: 0.7086 - val_loss: 1.1653
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.4883 - loss: 1.6430 - val_accuracy: 0.7508 - val_loss: 1.0642
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.5175 - loss: 1.6068 - val_accuracy: 0.7646 - val_loss: 1.0248
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 249ms/step - accuracy: 0.5365 - loss: 1.5686 - val_accuracy: 0.7931 - val_loss: 1.0106
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 249ms/step - accuracy: 0.5119 - loss: 1.5864 - val_accuracy: 0.7651 - val_loss: 1.0494
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 247ms/step - accuracy: 0.5331 - loss: 1.5409 - val_accuracy: 0.7772 - val_loss: 1.0059
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.5395 - loss: 1.5880 - val_accuracy: 0.7972 - val_loss: 0.9957
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.5290 - loss: 1.5637 - val_accuracy: 0.7952 - val_loss: 0.9982
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - accuracy: 0.5400 - loss: 1.5633 - val_accuracy: 0.8006 - val_loss: 0.9991
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.5369 - loss: 1.5551 - val_accuracy: 0.7860 - val_loss: 1.0009
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.5414 - loss: 1.5461 - val_accuracy: 0.7830 - val_loss: 1.0205
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5565 - loss: 1.5365 - val_accuracy: 0.8043 - val_loss: 0.9894
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 242ms/step - accuracy: 0.5504 - loss: 1.5426 - val_accuracy: 0.7701 - val_loss: 1.0120
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 243ms/step - accuracy: 0.5532 - loss: 1.5248 - val_accuracy: 0.8014 - val_loss: 0.9986
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 246ms/step - accuracy: 0.5494 - loss: 1.5305 - val_accuracy: 0.7893 - val_loss: 0.9949
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - accuracy: 0.5432 - loss: 1.5443 - val_accuracy: 0.8169 - val_loss: 0.9711
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 245ms/step - accuracy: 0.5489 - loss: 1.5168 - val_accuracy: 0.7738 - val_loss: 1.0231
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - accuracy: 0.5602 - loss: 1.5186 - val_accuracy: 0.7914 - val_loss: 1.0033
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 257ms/step - accuracy: 0.5562 - loss: 1.5210 - val_accuracy: 0.8039 - val_loss: 0.9978
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5661 - loss: 1.4876 - val_accuracy: 0.7918 - val_loss: 0.9956
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 247ms/step - accuracy: 0.5536 - loss: 1.5205 - val_accuracy: 0.8043 - val_loss: 0.9956
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 254ms/step - accuracy: 0.5435 - loss: 1.5169 - val_accuracy: 0.7809 - val_loss: 0.9889
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5520 - loss: 1.5312 - val_accuracy: 0.8127 - val_loss: 0.9897
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - accuracy: 0.5577 - loss: 1.5432 - val_accuracy: 0.8110 - val_loss: 0.9719
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.5375 - loss: 1.5408 - val_accuracy: 0.8035 - val_loss: 0.9947
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 252ms/step - accuracy: 0.5679 - loss: 1.4904 - val_accuracy: 0.8227 - val_loss: 0.9699
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 256ms/step - accuracy: 0.5560 - loss: 1.5231 - val_accuracy: 0.8027 - val_loss: 0.9775
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 247ms/step - accuracy: 0.5472 - loss: 1.5124 - val_accuracy: 0.8064 - val_loss: 0.9844
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 249ms/step - accuracy: 0.5395 - loss: 1.5385 - val_accuracy: 0.8102 - val_loss: 0.9680
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 251ms/step - accuracy: 0.5626 - loss: 1.5042 - val_accuracy: 0.8131 - val_loss: 0.9828
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 249ms/step - accuracy: 0.5720 - loss: 1.4979 - val_accuracy: 0.7805 - val_loss: 1.0055
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5679 - loss: 1.4927 - val_accuracy: 0.8077 - val_loss: 0.9917
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 248ms/step - accuracy: 0.5573 - loss: 1.5040 - val_accuracy: 0.7964 - val_loss: 0.9888
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 21s 242ms/step - accuracy: 0.5541 - loss: 1.5206 - val_accuracy: 0.8018 - val_loss: 0.9846
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 253ms/step - accuracy: 0.5593 - loss: 1.5262 - val_accuracy: 0.8102 - val_loss: 0.9794
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 22s 250ms/step - accuracy: 0.5577 - loss: 1.4849 - val_accuracy: 0.8227 - val_loss: 0.9734
# Final validation accuracy: 82.27%

# %%
# store information about the run
with open("weights/transfer_learning/"+ run_dir_name + "/hyperparameters.txt", "w") as file:
    file.write(f"Hyperparameters:\n{hyperparameters}\n\n")
    file.write(f"Final validation accuracy: {final_val_accuracy}%\n\n")
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")

# %% [markdown]
# ### Then fine-tune the model

# %%
# Some hyperparameters may be changed or added for fine-tuning

hyperparameters['transfer_learning'] = 'fine_tuning'
hyperparameters['n_layers_frozen'] = 124
# optionally change the learning rate for fine tuning
hyperparameters['lr'] = 1e-4

# %%
# Re-load the model after transfer learning
ft_model = tfk.models.load_model(model_filepath, compile=False)


# Compila di nuovo il modello
ft_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# Select trainable layers

# %%
model_custom_layer = "efficientnetb4" # CHANGE THIS WITH THE MODEL

# Set the model layers as trainable
ft_model.get_layer(model_custom_layer).trainable = True

# Set all layers as non-trainable
for layer in ft_model.get_layer(model_custom_layer).layers:
    layer.trainable = False

# Enable training only for Conv2D and DepthwiseConv2D layers (THERE COULD BE DIFFERENT CHOICES IN OTHER MODELS)
for i, layer in enumerate(ft_model.get_layer(model_custom_layer).layers):
    if isinstance(layer, tf.keras.layers.Conv2D) or isinstance(layer, tf.keras.layers.DepthwiseConv2D):
        layer.trainable = True
        print(i, layer.name, type(layer).__name__, layer.trainable)
# Out:
# 5 stem_conv Conv2D True
# 8 block1a_dwconv DepthwiseConv2D True
# 13 block1a_se_reduce Conv2D True
# 14 block1a_se_expand Conv2D True
# 16 block1a_project_conv Conv2D True
# 18 block1b_dwconv DepthwiseConv2D True
# 23 block1b_se_reduce Conv2D True
# 24 block1b_se_expand Conv2D True
# 26 block1b_project_conv Conv2D True
# 30 block2a_expand_conv Conv2D True
# 34 block2a_dwconv DepthwiseConv2D True
# 39 block2a_se_reduce Conv2D True
# 40 block2a_se_expand Conv2D True
# 42 block2a_project_conv Conv2D True
# 44 block2b_expand_conv Conv2D True
# 47 block2b_dwconv DepthwiseConv2D True
# 52 block2b_se_reduce Conv2D True
# 53 block2b_se_expand Conv2D True
# 55 block2b_project_conv Conv2D True
# 59 block2c_expand_conv Conv2D True
# 62 block2c_dwconv DepthwiseConv2D True
# 67 block2c_se_reduce Conv2D True
# 68 block2c_se_expand Conv2D True
# 70 block2c_project_conv Conv2D True
# 74 block2d_expand_conv Conv2D True
# 77 block2d_dwconv DepthwiseConv2D True
# 82 block2d_se_reduce Conv2D True
# 83 block2d_se_expand Conv2D True
# 85 block2d_project_conv Conv2D True
# 89 block3a_expand_conv Conv2D True
# 93 block3a_dwconv DepthwiseConv2D True
# 98 block3a_se_reduce Conv2D True
# 99 block3a_se_expand Conv2D True
# 101 block3a_project_conv Conv2D True
# 103 block3b_expand_conv Conv2D True
# 106 block3b_dwconv DepthwiseConv2D True
# 111 block3b_se_reduce Conv2D True
# 112 block3b_se_expand Conv2D True
# 114 block3b_project_conv Conv2D True
# 118 block3c_expand_conv Conv2D True
# 121 block3c_dwconv DepthwiseConv2D True
# 126 block3c_se_reduce Conv2D True
# 127 block3c_se_expand Conv2D True
# 129 block3c_project_conv Conv2D True
# 133 block3d_expand_conv Conv2D True
# 136 block3d_dwconv DepthwiseConv2D True
# 141 block3d_se_reduce Conv2D True
# 142 block3d_se_expand Conv2D True
# 144 block3d_project_conv Conv2D True
# 148 block4a_expand_conv Conv2D True
# 152 block4a_dwconv DepthwiseConv2D True
# 157 block4a_se_reduce Conv2D True
# 158 block4a_se_expand Conv2D True
# 160 block4a_project_conv Conv2D True
# 162 block4b_expand_conv Conv2D True
# 165 block4b_dwconv DepthwiseConv2D True
# 170 block4b_se_reduce Conv2D True
# 171 block4b_se_expand Conv2D True
# 173 block4b_project_conv Conv2D True
# 177 block4c_expand_conv Conv2D True
# 180 block4c_dwconv DepthwiseConv2D True
# 185 block4c_se_reduce Conv2D True
# 186 block4c_se_expand Conv2D True
# 188 block4c_project_conv Conv2D True
# 192 block4d_expand_conv Conv2D True
# 195 block4d_dwconv DepthwiseConv2D True
# 200 block4d_se_reduce Conv2D True
# 201 block4d_se_expand Conv2D True
# 203 block4d_project_conv Conv2D True
# 207 block4e_expand_conv Conv2D True
# 210 block4e_dwconv DepthwiseConv2D True
# 215 block4e_se_reduce Conv2D True
# 216 block4e_se_expand Conv2D True
# 218 block4e_project_conv Conv2D True
# 222 block4f_expand_conv Conv2D True
# 225 block4f_dwconv DepthwiseConv2D True
# 230 block4f_se_reduce Conv2D True
# 231 block4f_se_expand Conv2D True
# 233 block4f_project_conv Conv2D True
# 237 block5a_expand_conv Conv2D True
# 240 block5a_dwconv DepthwiseConv2D True
# 245 block5a_se_reduce Conv2D True
# 246 block5a_se_expand Conv2D True
# 248 block5a_project_conv Conv2D True
# 250 block5b_expand_conv Conv2D True
# 253 block5b_dwconv DepthwiseConv2D True
# 258 block5b_se_reduce Conv2D True
# 259 block5b_se_expand Conv2D True
# 261 block5b_project_conv Conv2D True
# 265 block5c_expand_conv Conv2D True
# 268 block5c_dwconv DepthwiseConv2D True
# 273 block5c_se_reduce Conv2D True
# 274 block5c_se_expand Conv2D True
# 276 block5c_project_conv Conv2D True
# 280 block5d_expand_conv Conv2D True
# 283 block5d_dwconv DepthwiseConv2D True
# 288 block5d_se_reduce Conv2D True
# 289 block5d_se_expand Conv2D True
# 291 block5d_project_conv Conv2D True
# 295 block5e_expand_conv Conv2D True
# 298 block5e_dwconv DepthwiseConv2D True
# 303 block5e_se_reduce Conv2D True
# 304 block5e_se_expand Conv2D True
# 306 block5e_project_conv Conv2D True
# 310 block5f_expand_conv Conv2D True
# 313 block5f_dwconv DepthwiseConv2D True
# 318 block5f_se_reduce Conv2D True
# 319 block5f_se_expand Conv2D True
# 321 block5f_project_conv Conv2D True
# 325 block6a_expand_conv Conv2D True
# 329 block6a_dwconv DepthwiseConv2D True
# 334 block6a_se_reduce Conv2D True
# 335 block6a_se_expand Conv2D True
# 337 block6a_project_conv Conv2D True
# 339 block6b_expand_conv Conv2D True
# 342 block6b_dwconv DepthwiseConv2D True
# 347 block6b_se_reduce Conv2D True
# 348 block6b_se_expand Conv2D True
# 350 block6b_project_conv Conv2D True
# 354 block6c_expand_conv Conv2D True
# 357 block6c_dwconv DepthwiseConv2D True
# 362 block6c_se_reduce Conv2D True
# 363 block6c_se_expand Conv2D True
# 365 block6c_project_conv Conv2D True
# 369 block6d_expand_conv Conv2D True
# 372 block6d_dwconv DepthwiseConv2D True
# 377 block6d_se_reduce Conv2D True
# 378 block6d_se_expand Conv2D True
# 380 block6d_project_conv Conv2D True
# 384 block6e_expand_conv Conv2D True
# 387 block6e_dwconv DepthwiseConv2D True
# 392 block6e_se_reduce Conv2D True
# 393 block6e_se_expand Conv2D True
# 395 block6e_project_conv Conv2D True
# 399 block6f_expand_conv Conv2D True
# 402 block6f_dwconv DepthwiseConv2D True
# 407 block6f_se_reduce Conv2D True
# 408 block6f_se_expand Conv2D True
# 410 block6f_project_conv Conv2D True
# 414 block6g_expand_conv Conv2D True
# 417 block6g_dwconv DepthwiseConv2D True
# 422 block6g_se_reduce Conv2D True
# 423 block6g_se_expand Conv2D True
# 425 block6g_project_conv Conv2D True
# 429 block6h_expand_conv Conv2D True
# 432 block6h_dwconv DepthwiseConv2D True
# 437 block6h_se_reduce Conv2D True
# 438 block6h_se_expand Conv2D True
# 440 block6h_project_conv Conv2D True
# 444 block7a_expand_conv Conv2D True
# 447 block7a_dwconv DepthwiseConv2D True
# 452 block7a_se_reduce Conv2D True
# 453 block7a_se_expand Conv2D True
# 455 block7a_project_conv Conv2D True
# 457 block7b_expand_conv Conv2D True
# 460 block7b_dwconv DepthwiseConv2D True
# 465 block7b_se_reduce Conv2D True
# 466 block7b_se_expand Conv2D True
# 468 block7b_project_conv Conv2D True
# 472 top_conv Conv2D True

# %%
# Set the first N layers as non-trainable
for i, layer in enumerate(ft_model.get_layer(model_custom_layer).layers[:hyperparameters['n_layers_frozen']]):
    layer.trainable = False#prima parte non trainable

# Print layer indices, names, and trainability status
for i, layer in enumerate(ft_model.get_layer('efficientnetb4').layers):
    print(i, layer.name, layer.trainable)#last part to retrain
# Out:
# 0 input_layer_6 False
# 1 rescaling_12 False
# 2 normalization_6 False
# 3 rescaling_13 False
# 4 stem_conv_pad False
# 5 stem_conv False
# 6 stem_bn False
# 7 stem_activation False
# 8 block1a_dwconv False
# 9 block1a_bn False
# 10 block1a_activation False
# 11 block1a_se_squeeze False
# 12 block1a_se_reshape False
# 13 block1a_se_reduce False
# 14 block1a_se_expand False
# 15 block1a_se_excite False
# 16 block1a_project_conv False
# 17 block1a_project_bn False
# 18 block1b_dwconv False
# 19 block1b_bn False
# 20 block1b_activation False
# 21 block1b_se_squeeze False
# 22 block1b_se_reshape False
# 23 block1b_se_reduce False
# 24 block1b_se_expand False
# 25 block1b_se_excite False
# 26 block1b_project_conv False
# 27 block1b_project_bn False
# 28 block1b_drop False
# 29 block1b_add False
# 30 block2a_expand_conv False
# 31 block2a_expand_bn False
# 32 block2a_expand_activation False
# 33 block2a_dwconv_pad False
# 34 block2a_dwconv False
# 35 block2a_bn False
# 36 block2a_activation False
# 37 block2a_se_squeeze False
# 38 block2a_se_reshape False
# 39 block2a_se_reduce False
# 40 block2a_se_expand False
# 41 block2a_se_excite False
# 42 block2a_project_conv False
# 43 block2a_project_bn False
# 44 block2b_expand_conv False
# 45 block2b_expand_bn False
# 46 block2b_expand_activation False
# 47 block2b_dwconv False
# 48 block2b_bn False
# 49 block2b_activation False
# 50 block2b_se_squeeze False
# 51 block2b_se_reshape False
# 52 block2b_se_reduce False
# 53 block2b_se_expand False
# 54 block2b_se_excite False
# 55 block2b_project_conv False
# 56 block2b_project_bn False
# 57 block2b_drop False
# 58 block2b_add False
# 59 block2c_expand_conv False
# 60 block2c_expand_bn False
# 61 block2c_expand_activation False
# 62 block2c_dwconv False
# 63 block2c_bn False
# 64 block2c_activation False
# 65 block2c_se_squeeze False
# 66 block2c_se_reshape False
# 67 block2c_se_reduce False
# 68 block2c_se_expand False
# 69 block2c_se_excite False
# 70 block2c_project_conv False
# 71 block2c_project_bn False
# 72 block2c_drop False
# 73 block2c_add False
# 74 block2d_expand_conv False
# 75 block2d_expand_bn False
# 76 block2d_expand_activation False
# 77 block2d_dwconv False
# 78 block2d_bn False
# 79 block2d_activation False
# 80 block2d_se_squeeze False
# 81 block2d_se_reshape False
# 82 block2d_se_reduce False
# 83 block2d_se_expand False
# 84 block2d_se_excite False
# 85 block2d_project_conv False
# 86 block2d_project_bn False
# 87 block2d_drop False
# 88 block2d_add False
# 89 block3a_expand_conv False
# 90 block3a_expand_bn False
# 91 block3a_expand_activation False
# 92 block3a_dwconv_pad False
# 93 block3a_dwconv False
# 94 block3a_bn False
# 95 block3a_activation False
# 96 block3a_se_squeeze False
# 97 block3a_se_reshape False
# 98 block3a_se_reduce False
# 99 block3a_se_expand False
# 100 block3a_se_excite False
# 101 block3a_project_conv False
# 102 block3a_project_bn False
# 103 block3b_expand_conv False
# 104 block3b_expand_bn False
# 105 block3b_expand_activation False
# 106 block3b_dwconv False
# 107 block3b_bn False
# 108 block3b_activation False
# 109 block3b_se_squeeze False
# 110 block3b_se_reshape False
# 111 block3b_se_reduce False
# 112 block3b_se_expand False
# 113 block3b_se_excite False
# 114 block3b_project_conv False
# 115 block3b_project_bn False
# 116 block3b_drop False
# 117 block3b_add False
# 118 block3c_expand_conv False
# 119 block3c_expand_bn False
# 120 block3c_expand_activation False
# 121 block3c_dwconv False
# 122 block3c_bn False
# 123 block3c_activation False
# 124 block3c_se_squeeze False
# 125 block3c_se_reshape False
# 126 block3c_se_reduce True
# 127 block3c_se_expand True
# 128 block3c_se_excite False
# 129 block3c_project_conv True
# 130 block3c_project_bn False
# 131 block3c_drop False
# 132 block3c_add False
# 133 block3d_expand_conv True
# 134 block3d_expand_bn False
# 135 block3d_expand_activation False
# 136 block3d_dwconv True
# 137 block3d_bn False
# 138 block3d_activation False
# 139 block3d_se_squeeze False
# 140 block3d_se_reshape False
# 141 block3d_se_reduce True
# 142 block3d_se_expand True
# 143 block3d_se_excite False
# 144 block3d_project_conv True
# 145 block3d_project_bn False
# 146 block3d_drop False
# 147 block3d_add False
# 148 block4a_expand_conv True
# 149 block4a_expand_bn False
# 150 block4a_expand_activation False
# 151 block4a_dwconv_pad False
# 152 block4a_dwconv True
# 153 block4a_bn False
# 154 block4a_activation False
# 155 block4a_se_squeeze False
# 156 block4a_se_reshape False
# 157 block4a_se_reduce True
# 158 block4a_se_expand True
# 159 block4a_se_excite False
# 160 block4a_project_conv True
# 161 block4a_project_bn False
# 162 block4b_expand_conv True
# 163 block4b_expand_bn False
# 164 block4b_expand_activation False
# 165 block4b_dwconv True
# 166 block4b_bn False
# 167 block4b_activation False
# 168 block4b_se_squeeze False
# 169 block4b_se_reshape False
# 170 block4b_se_reduce True
# 171 block4b_se_expand True
# 172 block4b_se_excite False
# 173 block4b_project_conv True
# 174 block4b_project_bn False
# 175 block4b_drop False
# 176 block4b_add False
# 177 block4c_expand_conv True
# 178 block4c_expand_bn False
# 179 block4c_expand_activation False
# 180 block4c_dwconv True
# 181 block4c_bn False
# 182 block4c_activation False
# 183 block4c_se_squeeze False
# 184 block4c_se_reshape False
# 185 block4c_se_reduce True
# 186 block4c_se_expand True
# 187 block4c_se_excite False
# 188 block4c_project_conv True
# 189 block4c_project_bn False
# 190 block4c_drop False
# 191 block4c_add False
# 192 block4d_expand_conv True
# 193 block4d_expand_bn False
# 194 block4d_expand_activation False
# 195 block4d_dwconv True
# 196 block4d_bn False
# 197 block4d_activation False
# 198 block4d_se_squeeze False
# 199 block4d_se_reshape False
# 200 block4d_se_reduce True
# 201 block4d_se_expand True
# 202 block4d_se_excite False
# 203 block4d_project_conv True
# 204 block4d_project_bn False
# 205 block4d_drop False
# 206 block4d_add False
# 207 block4e_expand_conv True
# 208 block4e_expand_bn False
# 209 block4e_expand_activation False
# 210 block4e_dwconv True
# 211 block4e_bn False
# 212 block4e_activation False
# 213 block4e_se_squeeze False
# 214 block4e_se_reshape False
# 215 block4e_se_reduce True
# 216 block4e_se_expand True
# 217 block4e_se_excite False
# 218 block4e_project_conv True
# 219 block4e_project_bn False
# 220 block4e_drop False
# 221 block4e_add False
# 222 block4f_expand_conv True
# 223 block4f_expand_bn False
# 224 block4f_expand_activation False
# 225 block4f_dwconv True
# 226 block4f_bn False
# 227 block4f_activation False
# 228 block4f_se_squeeze False
# 229 block4f_se_reshape False
# 230 block4f_se_reduce True
# 231 block4f_se_expand True
# 232 block4f_se_excite False
# 233 block4f_project_conv True
# 234 block4f_project_bn False
# 235 block4f_drop False
# 236 block4f_add False
# 237 block5a_expand_conv True
# 238 block5a_expand_bn False
# 239 block5a_expand_activation False
# 240 block5a_dwconv True
# 241 block5a_bn False
# 242 block5a_activation False
# 243 block5a_se_squeeze False
# 244 block5a_se_reshape False
# 245 block5a_se_reduce True
# 246 block5a_se_expand True
# 247 block5a_se_excite False
# 248 block5a_project_conv True
# 249 block5a_project_bn False
# 250 block5b_expand_conv True
# 251 block5b_expand_bn False
# 252 block5b_expand_activation False
# 253 block5b_dwconv True
# 254 block5b_bn False
# 255 block5b_activation False
# 256 block5b_se_squeeze False
# 257 block5b_se_reshape False
# 258 block5b_se_reduce True
# 259 block5b_se_expand True
# 260 block5b_se_excite False
# 261 block5b_project_conv True
# 262 block5b_project_bn False
# 263 block5b_drop False
# 264 block5b_add False
# 265 block5c_expand_conv True
# 266 block5c_expand_bn False
# 267 block5c_expand_activation False
# 268 block5c_dwconv True
# 269 block5c_bn False
# 270 block5c_activation False
# 271 block5c_se_squeeze False
# 272 block5c_se_reshape False
# 273 block5c_se_reduce True
# 274 block5c_se_expand True
# 275 block5c_se_excite False
# 276 block5c_project_conv True
# 277 block5c_project_bn False
# 278 block5c_drop False
# 279 block5c_add False
# 280 block5d_expand_conv True
# 281 block5d_expand_bn False
# 282 block5d_expand_activation False
# 283 block5d_dwconv True
# 284 block5d_bn False
# 285 block5d_activation False
# 286 block5d_se_squeeze False
# 287 block5d_se_reshape False
# 288 block5d_se_reduce True
# 289 block5d_se_expand True
# 290 block5d_se_excite False
# 291 block5d_project_conv True
# 292 block5d_project_bn False
# 293 block5d_drop False
# 294 block5d_add False
# 295 block5e_expand_conv True
# 296 block5e_expand_bn False
# 297 block5e_expand_activation False
# 298 block5e_dwconv True
# 299 block5e_bn False
# 300 block5e_activation False
# 301 block5e_se_squeeze False
# 302 block5e_se_reshape False
# 303 block5e_se_reduce True
# 304 block5e_se_expand True
# 305 block5e_se_excite False
# 306 block5e_project_conv True
# 307 block5e_project_bn False
# 308 block5e_drop False
# 309 block5e_add False
# 310 block5f_expand_conv True
# 311 block5f_expand_bn False
# 312 block5f_expand_activation False
# 313 block5f_dwconv True
# 314 block5f_bn False
# 315 block5f_activation False
# 316 block5f_se_squeeze False
# 317 block5f_se_reshape False
# 318 block5f_se_reduce True
# 319 block5f_se_expand True
# 320 block5f_se_excite False
# 321 block5f_project_conv True
# 322 block5f_project_bn False
# 323 block5f_drop False
# 324 block5f_add False
# 325 block6a_expand_conv True
# 326 block6a_expand_bn False
# 327 block6a_expand_activation False
# 328 block6a_dwconv_pad False
# 329 block6a_dwconv True
# 330 block6a_bn False
# 331 block6a_activation False
# 332 block6a_se_squeeze False
# 333 block6a_se_reshape False
# 334 block6a_se_reduce True
# 335 block6a_se_expand True
# 336 block6a_se_excite False
# 337 block6a_project_conv True
# 338 block6a_project_bn False
# 339 block6b_expand_conv True
# 340 block6b_expand_bn False
# 341 block6b_expand_activation False
# 342 block6b_dwconv True
# 343 block6b_bn False
# 344 block6b_activation False
# 345 block6b_se_squeeze False
# 346 block6b_se_reshape False
# 347 block6b_se_reduce True
# 348 block6b_se_expand True
# 349 block6b_se_excite False
# 350 block6b_project_conv True
# 351 block6b_project_bn False
# 352 block6b_drop False
# 353 block6b_add False
# 354 block6c_expand_conv True
# 355 block6c_expand_bn False
# 356 block6c_expand_activation False
# 357 block6c_dwconv True
# 358 block6c_bn False
# 359 block6c_activation False
# 360 block6c_se_squeeze False
# 361 block6c_se_reshape False
# 362 block6c_se_reduce True
# 363 block6c_se_expand True
# 364 block6c_se_excite False
# 365 block6c_project_conv True
# 366 block6c_project_bn False
# 367 block6c_drop False
# 368 block6c_add False
# 369 block6d_expand_conv True
# 370 block6d_expand_bn False
# 371 block6d_expand_activation False
# 372 block6d_dwconv True
# 373 block6d_bn False
# 374 block6d_activation False
# 375 block6d_se_squeeze False
# 376 block6d_se_reshape False
# 377 block6d_se_reduce True
# 378 block6d_se_expand True
# 379 block6d_se_excite False
# 380 block6d_project_conv True
# 381 block6d_project_bn False
# 382 block6d_drop False
# 383 block6d_add False
# 384 block6e_expand_conv True
# 385 block6e_expand_bn False
# 386 block6e_expand_activation False
# 387 block6e_dwconv True
# 388 block6e_bn False
# 389 block6e_activation False
# 390 block6e_se_squeeze False
# 391 block6e_se_reshape False
# 392 block6e_se_reduce True
# 393 block6e_se_expand True
# 394 block6e_se_excite False
# 395 block6e_project_conv True
# 396 block6e_project_bn False
# 397 block6e_drop False
# 398 block6e_add False
# 399 block6f_expand_conv True
# 400 block6f_expand_bn False
# 401 block6f_expand_activation False
# 402 block6f_dwconv True
# 403 block6f_bn False
# 404 block6f_activation False
# 405 block6f_se_squeeze False
# 406 block6f_se_reshape False
# 407 block6f_se_reduce True
# 408 block6f_se_expand True
# 409 block6f_se_excite False
# 410 block6f_project_conv True
# 411 block6f_project_bn False
# 412 block6f_drop False
# 413 block6f_add False
# 414 block6g_expand_conv True
# 415 block6g_expand_bn False
# 416 block6g_expand_activation False
# 417 block6g_dwconv True
# 418 block6g_bn False
# 419 block6g_activation False
# 420 block6g_se_squeeze False
# 421 block6g_se_reshape False
# 422 block6g_se_reduce True
# 423 block6g_se_expand True
# 424 block6g_se_excite False
# 425 block6g_project_conv True
# 426 block6g_project_bn False
# 427 block6g_drop False
# 428 block6g_add False
# 429 block6h_expand_conv True
# 430 block6h_expand_bn False
# 431 block6h_expand_activation False
# 432 block6h_dwconv True
# 433 block6h_bn False
# 434 block6h_activation False
# 435 block6h_se_squeeze False
# 436 block6h_se_reshape False
# 437 block6h_se_reduce True
# 438 block6h_se_expand True
# 439 block6h_se_excite False
# 440 block6h_project_conv True
# 441 block6h_project_bn False
# 442 block6h_drop False
# 443 block6h_add False
# 444 block7a_expand_conv True
# 445 block7a_expand_bn False
# 446 block7a_expand_activation False
# 447 block7a_dwconv True
# 448 block7a_bn False
# 449 block7a_activation False
# 450 block7a_se_squeeze False
# 451 block7a_se_reshape False
# 452 block7a_se_reduce True
# 453 block7a_se_expand True
# 454 block7a_se_excite False
# 455 block7a_project_conv True
# 456 block7a_project_bn False
# 457 block7b_expand_conv True
# 458 block7b_expand_bn False
# 459 block7b_expand_activation False
# 460 block7b_dwconv True
# 461 block7b_bn False
# 462 block7b_activation False
# 463 block7b_se_squeeze False
# 464 block7b_se_reshape False
# 465 block7b_se_reduce True
# 466 block7b_se_expand True
# 467 block7b_se_excite False
# 468 block7b_project_conv True
# 469 block7b_project_bn False
# 470 block7b_drop False
# 471 block7b_add False
# 472 top_conv True
# 473 top_bn False
# 474 top_activation False
# 475 avg_pool False

# %%
lr_schedule2 = ExponentialDecay(
    initial_learning_rate=1e-5,
    decay_steps=100, decay_rate=0.96,
    staircase=True)

optimizer2 = Lion(
    learning_rate=lr_schedule2,
    beta_1=0.9,
    beta_2=0.99,
    weight_decay=1e-2,
    use_ema=False  # Setta True se vuoi usare EMA, ma normalmente è disattivato per Lion
)

# %%
# Compile the model
ft_model.compile(loss=tfk.losses.CategoricalCrossentropy(label_smoothing=hyperparameters['label_smoothing']), optimizer=tfk.optimizers.Adam(hyperparameters['lr'],weight_decay=hyperparameters['weight_decay']), metrics=['accuracy'])

# %% [markdown]
# training

# %%
# Fine-tune the model
ft_history = ft_model.fit(
    train_ds_rand,
    batch_size=(hyperparameters['batch_size'] if not hyperparameters['mixup'] else None),
    epochs=hyperparameters['epochs'],
    validation_data=val_ds,
    class_weight=(class_weights if hyperparameters['weighted_loss'] else None),
    callbacks=[tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=hyperparameters['patience'], restore_best_weights=True)]
).history

# Calculate and print the final validation accuracy
final_val_accuracy = round(max(ft_history['val_accuracy'])* 100, 2)
print(f'Final validation accuracy: {final_val_accuracy}%')

# Save the trained model to a file, including final accuracy in the filename
run_dir_name = MODEL_NAME + str(final_val_accuracy) + "__" + time().strftime("_%Y-%m-%d_%H.%M")
model_filename = 'weights.keras'
os.makedirs("weights/"+ run_dir_name, exist_ok=True)
ft_model_filepath = "weights/"+ run_dir_name + "/" + model_filename
ft_model.save(ft_model_filepath)

# Delete the model to free up resources
#del ft_model
# Out:
# Epoch 1/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 127s 811ms/step - accuracy: 0.6301 - loss: 1.4118 - val_accuracy: 0.9181 - val_loss: 0.7110
# Epoch 2/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 345ms/step - accuracy: 0.7676 - loss: 1.1445 - val_accuracy: 0.9189 - val_loss: 0.6727
# Epoch 3/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 30s 355ms/step - accuracy: 0.8118 - loss: 1.0440 - val_accuracy: 0.9557 - val_loss: 0.5940
# Epoch 4/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 341ms/step - accuracy: 0.8331 - loss: 1.0149 - val_accuracy: 0.9490 - val_loss: 0.5970
# Epoch 5/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 344ms/step - accuracy: 0.8502 - loss: 0.9871 - val_accuracy: 0.9561 - val_loss: 0.5841
# Epoch 6/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 349ms/step - accuracy: 0.8691 - loss: 0.9413 - val_accuracy: 0.9682 - val_loss: 0.5506
# Epoch 7/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 346ms/step - accuracy: 0.8761 - loss: 0.9136 - val_accuracy: 0.9749 - val_loss: 0.5393
# Epoch 8/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 350ms/step - accuracy: 0.8894 - loss: 0.9081 - val_accuracy: 0.9762 - val_loss: 0.5361
# Epoch 9/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 31s 373ms/step - accuracy: 0.8801 - loss: 0.9167 - val_accuracy: 0.9699 - val_loss: 0.5471
# Epoch 10/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 347ms/step - accuracy: 0.8978 - loss: 0.8888 - val_accuracy: 0.9774 - val_loss: 0.5233
# Epoch 11/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 341ms/step - accuracy: 0.8928 - loss: 0.8814 - val_accuracy: 0.9758 - val_loss: 0.5315
# Epoch 12/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 342ms/step - accuracy: 0.8908 - loss: 0.8802 - val_accuracy: 0.9716 - val_loss: 0.5382
# Epoch 13/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 345ms/step - accuracy: 0.8962 - loss: 0.8771 - val_accuracy: 0.9820 - val_loss: 0.5174
# Epoch 14/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 348ms/step - accuracy: 0.9026 - loss: 0.8553 - val_accuracy: 0.9829 - val_loss: 0.5143
# Epoch 15/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 338ms/step - accuracy: 0.9035 - loss: 0.8641 - val_accuracy: 0.9808 - val_loss: 0.5131
# Epoch 16/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.8977 - loss: 0.8578 - val_accuracy: 0.9812 - val_loss: 0.5173
# Epoch 17/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 343ms/step - accuracy: 0.9026 - loss: 0.8531 - val_accuracy: 0.9812 - val_loss: 0.5199
# Epoch 18/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 338ms/step - accuracy: 0.9039 - loss: 0.8710 - val_accuracy: 0.9804 - val_loss: 0.5153
# Epoch 19/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 337ms/step - accuracy: 0.9049 - loss: 0.8613 - val_accuracy: 0.9816 - val_loss: 0.5171
# Epoch 20/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 341ms/step - accuracy: 0.9096 - loss: 0.8420 - val_accuracy: 0.9829 - val_loss: 0.5112
# Epoch 21/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 342ms/step - accuracy: 0.9146 - loss: 0.8428 - val_accuracy: 0.9845 - val_loss: 0.5077
# Epoch 22/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 338ms/step - accuracy: 0.9099 - loss: 0.8370 - val_accuracy: 0.9829 - val_loss: 0.5227
# Epoch 23/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.9263 - loss: 0.8245 - val_accuracy: 0.9766 - val_loss: 0.5212
# Epoch 24/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.9082 - loss: 0.8485 - val_accuracy: 0.9841 - val_loss: 0.5117
# Epoch 25/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 347ms/step - accuracy: 0.9191 - loss: 0.8363 - val_accuracy: 0.9866 - val_loss: 0.5054
# Epoch 26/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 339ms/step - accuracy: 0.9198 - loss: 0.8254 - val_accuracy: 0.9812 - val_loss: 0.5160
# Epoch 27/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.9227 - loss: 0.8285 - val_accuracy: 0.9866 - val_loss: 0.5077
# Epoch 28/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 342ms/step - accuracy: 0.9283 - loss: 0.8128 - val_accuracy: 0.9841 - val_loss: 0.5096
# Epoch 29/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 339ms/step - accuracy: 0.9100 - loss: 0.8490 - val_accuracy: 0.9820 - val_loss: 0.5144
# Epoch 30/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 337ms/step - accuracy: 0.9176 - loss: 0.8282 - val_accuracy: 0.9837 - val_loss: 0.5070
# Epoch 31/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 338ms/step - accuracy: 0.9225 - loss: 0.8134 - val_accuracy: 0.9858 - val_loss: 0.5084
# Epoch 32/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 337ms/step - accuracy: 0.9312 - loss: 0.8081 - val_accuracy: 0.9849 - val_loss: 0.5087
# Epoch 33/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 341ms/step - accuracy: 0.9282 - loss: 0.8103 - val_accuracy: 0.9879 - val_loss: 0.4990
# Epoch 34/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 338ms/step - accuracy: 0.9213 - loss: 0.8154 - val_accuracy: 0.9870 - val_loss: 0.5057
# Epoch 35/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 336ms/step - accuracy: 0.9278 - loss: 0.8170 - val_accuracy: 0.9870 - val_loss: 0.5050
# Epoch 36/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 347ms/step - accuracy: 0.9283 - loss: 0.7949 - val_accuracy: 0.9870 - val_loss: 0.5034
# Epoch 37/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 342ms/step - accuracy: 0.9332 - loss: 0.7890 - val_accuracy: 0.9883 - val_loss: 0.5033
# Epoch 38/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 340ms/step - accuracy: 0.9301 - loss: 0.8145 - val_accuracy: 0.9875 - val_loss: 0.5017
# Epoch 39/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 343ms/step - accuracy: 0.9252 - loss: 0.8058 - val_accuracy: 0.9887 - val_loss: 0.4993
# Epoch 40/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 340ms/step - accuracy: 0.9255 - loss: 0.8068 - val_accuracy: 0.9870 - val_loss: 0.5004
# Epoch 41/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 341ms/step - accuracy: 0.9310 - loss: 0.7983 - val_accuracy: 0.9862 - val_loss: 0.5039
# Epoch 42/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 350ms/step - accuracy: 0.9261 - loss: 0.7978 - val_accuracy: 0.9858 - val_loss: 0.5026
# Epoch 43/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 344ms/step - accuracy: 0.9283 - loss: 0.8073 - val_accuracy: 0.9770 - val_loss: 0.5211
# Epoch 44/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 348ms/step - accuracy: 0.9293 - loss: 0.8045 - val_accuracy: 0.9841 - val_loss: 0.5048
# Epoch 45/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 344ms/step - accuracy: 0.9272 - loss: 0.8069 - val_accuracy: 0.9883 - val_loss: 0.4970
# Epoch 46/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 339ms/step - accuracy: 0.9322 - loss: 0.8036 - val_accuracy: 0.9849 - val_loss: 0.5041
# Epoch 47/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 29s 347ms/step - accuracy: 0.9315 - loss: 0.7941 - val_accuracy: 0.9879 - val_loss: 0.5014
# Epoch 48/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 340ms/step - accuracy: 0.9363 - loss: 0.7844 - val_accuracy: 0.9862 - val_loss: 0.5005
# Epoch 49/200
# 75/75 ━━━━━━━━━━━━━━━━━━━━ 28s 340ms/step - accuracy: 0.9302 - loss: 0.8021 - val_accuracy: 0.9849 - val_loss: 0.5064
# Final validation accuracy: 98.87%

# %% [markdown]
# ## Visualize training

# %%
# Create figure and subplots for loss and accuracy
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(15, 6))

# Plot categorical cross-entropy loss for both Transfer Learning and Fine Tuning stages
ax1.plot(tl_history['loss'], alpha=0.3, color='#4D61E2', linestyle='--')
ax1.plot(tl_history['val_loss'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax1.plot(ft_history['loss'], alpha=0.3, color='#408537', linestyle='--')
ax1.plot(ft_history['val_loss'], label='Fine Tuning', alpha=0.8, color='#408537')
ax1.set_title('Categorical Crossentropy')
ax1.legend(loc='upper left')
ax1.grid(alpha=0.3)

# Plot accuracy for both Transfer Learning and Fine Tuning stages
ax2.plot(tl_history['accuracy'], alpha=0.3, color='#4D61E2', linestyle='--')
ax2.plot(tl_history['val_accuracy'], label='Transfer Learning', alpha=0.8, color='#4D61E2')
ax2.plot(ft_history['accuracy'], alpha=0.3, color='#408537', linestyle='--')
ax2.plot(ft_history['val_accuracy'], label='Fine Tuning', alpha=0.8, color='#408537')
ax2.set_title('Accuracy')
ax2.set_ylim([min(tl_history['val_accuracy']) * 0.95, max(ft_history['val_accuracy']) * 1.05])
ax2.grid(alpha=0.3)

# Adjust layout to prevent overlap and display the plots
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Visualize results

# %%
# Load the fine-tuned MobileNetV2 model for prediction on external images
ft_bn_model = tfk.models.load_model(ft_model_filepath, compile=False)

# Compila di nuovo il modello
ft_bn_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score, confusion_matrix
# Predict class probabilities and get predicted classes
test_predictions = ft_bn_model.predict(X_val, verbose=0)
test_predictions = np.argmax(test_predictions, axis=-1)

# Extract ground truth classes
test_gt = np.argmax(y_val, axis=-1)

# Calculate and display validation set accuracy
test_accuracy = accuracy_score(test_gt, test_predictions)
print(f'Accuracy score over the validation set: {round(test_accuracy, 4)}')

# Calculate and display validation set precision
test_precision = precision_score(test_gt, test_predictions, average='weighted')
print(f'Precision score over the validation set: {round(test_precision, 4)}')

# Calculate and display validation set recall
test_recall = recall_score(test_gt, test_predictions, average='weighted')
print(f'Recall score over the validation set: {round(test_recall, 4)}')

# Calculate and display validation set F1 score
test_f1 = f1_score(test_gt, test_predictions, average='weighted')
print(f'F1 score over the validation set: {round(test_f1, 4)}')

# Compute the confusion matrix
cm = confusion_matrix(test_gt, test_predictions)

# Create labels combining confusion matrix values
labels = np.array([f"{num}" for num in cm.flatten()]).reshape(cm.shape)

# Plot the confusion matrix with class labels
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=labels, fmt='', xticklabels=['0','1','2','3','4','5','6','7'], yticklabels=['0','1','2','3','4','5','6','7'], cmap='Blues')
plt.xlabel('True Labels')
plt.ylabel('Predict')
plt.show()
# Out:
# Accuracy score over the validation set: 0.9887
# Precision score over the validation set: 0.9888
# Recall score over the validation set: 0.9887
# F1 score over the validation set: 0.9887

# %% [markdown]
# ### Finally store comments and hyperparameters

# %%
RUN_COMMENTS = "additional considerations..."
# Save the hyperparameters and results to a file
with open("weights/"+ run_dir_name + "/hyperparameters.txt", "w") as file:
    file.write(f"Hyperparameters:\n{hyperparameters}\n\n")
    file.write(f"Final validation accuracy: {final_val_accuracy}%\n\n")
    file.write(f"Comments: {RUN_COMMENTS}\n\n")
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")
# write description and comments in a separate file as well
with open("weights/"+ run_dir_name + "/description.txt", "w") as file:
    file.write(f"Run description: {RUN_DESCRIPTION}\n\n")
    file.write(f"Comments: {RUN_COMMENTS}\n\n")
